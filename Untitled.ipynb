# %%
import pandas as pd
df = pd.read_csv('data/raw_claims.csv')
print(df.head())
print(df.head)
print(df.columns.tolist())
print(df.isnull().sum())
print(df[df['Claim_Status'].isnull()]['Claim_Count'].value_counts())
# Out:
#   Policy_ID Policy_Number Customer_ID State     Region              Product  \
# 0  POL00001     PN-205907   CUST00001    MD      South                 Auto
# 1  POL00002     PN-944151   CUST00002    MA  Northeast                 Auto
# 2  POL00003     PN-711878   CUST00003    CT  Northeast  Commercial Property
# 3  POL00004     PN-654816   CUST00004    OH    Midwest  Commercial Property
# 4  POL00005     PN-624902   CUST00005    OH    Midwest  Commercial Property
#
#       Line_of_Business            Agent     Underwriter Policy_Status  ...  \
# 0        Personal Auto  Kimberly Garcia   Paul Williams        Active  ...
# 1        Personal Auto   Kimberly Allen     Mark Miller        Active  ...
# 2  Commercial Property     Ashley Brown     Donna Davis        Active  ...
# 3  Commercial Property     Thomas Brown       Brian Lee        Active  ...
# 4  Commercial Property     Angela Allen  Donna Anderson        Active  ...
#
#   Claim_Count Claim_Amount Paid_Claim_Amount  Outstanding_Reserve  \
# 0           1      4202.30           4061.10                  0.0
# 1           0         0.00              0.00                  0.0
# 2           0         0.00              0.00                  0.0
# 3           0         0.00              0.00                  0.0
# 4           1     23284.19          22696.26                  0.0
#
#      Coverage_Type  Claim_Status  Claim_Type   Loss_Date  Reported_Date  \
# 0        Collision        Closed     Weather  2026-02-15     2026-02-16
# 1  Personal Injury           NaN         NaN         NaN            NaN
# 2        Liability           NaN         NaN         NaN            NaN
# 3        Liability           NaN         NaN         NaN            NaN
# 4         Property        Closed        Fire  2025-06-23     2025-06-30
#
#   Distribution_Channel
# 0               Online
# 1               Direct
# 2                Agent
# 3                Agent
# 4                Agent
#
# [5 rows x 25 columns]
# <bound method NDFrame.head of     Policy_ID Policy_Number Customer_ID State     Region              Product  \
# 0    POL00001     PN-205907   CUST00001    MD      South                 Auto
# 1    POL00002     PN-944151   CUST00002    MA  Northeast                 Auto
# 2    POL00003     PN-711878   CUST00003    CT  Northeast  Commercial Property
# 3    POL00004     PN-654816   CUST00004    OH    Midwest  Commercial Property
# 4    POL00005     PN-624902   CUST00005    OH    Midwest  Commercial Property
# ..        ...           ...         ...   ...        ...                  ...
# 495  POL00496     PN-177971   CUST00422    MA  Northeast                 Auto
# 496  POL00497     PN-849149   CUST00423    TX      South                 Home
# 497  POL00498     PN-386939   CUST00063    CT  Northeast                 Auto
# 498  POL00499     PN-150293   CUST00424    FL      South                 Auto
# 499  POL00500     PN-626625   CUST00425    MD      South                 Home
#
#         Line_of_Business             Agent     Underwriter Policy_Status  ...  \
# 0          Personal Auto   Kimberly Garcia   Paul Williams        Active  ...
# 1          Personal Auto    Kimberly Allen     Mark Miller        Active  ...
# 2    Commercial Property      Ashley Brown     Donna Davis        Active  ...
# 3    Commercial Property      Thomas Brown       Brian Lee        Active  ...
# 4    Commercial Property      Angela Allen  Donna Anderson        Active  ...
# ..                   ...               ...             ...           ...  ...
# 495        Personal Auto      Sandra Lewis    Maria Harris       Expired  ...
# 496           Homeowners    Jennifer Moore  Kevin Williams        Active  ...
# 497        Personal Auto    Jennifer Jones       Brian Lee     Cancelled  ...
# 498        Personal Auto   Steven Thompson    Maria Harris        Active  ...
# 499           Homeowners  Carlos Rodriguez    Edward White       Expired  ...
#
#     Claim_Count Claim_Amount Paid_Claim_Amount  Outstanding_Reserve  \
# 0             1      4202.30           4061.10                 0.00
# 1             0         0.00              0.00                 0.00
# 2             0         0.00              0.00                 0.00
# 3             0         0.00              0.00                 0.00
# 4             1     23284.19          22696.26                 0.00
# ..          ...          ...               ...                  ...
# 495           0         0.00              0.00                 0.00
# 496           1      2177.34            989.87              1108.41
# 497           0         0.00              0.00                 0.00
# 498           2     13609.28          12463.98                 0.00
# 499           1      3579.31            511.57              3002.94
#
#        Coverage_Type  Claim_Status  Claim_Type   Loss_Date  Reported_Date  \
# 0          Collision        Closed     Weather  2026-02-15     2026-02-16
# 1    Personal Injury           NaN         NaN         NaN            NaN
# 2          Liability           NaN         NaN         NaN            NaN
# 3          Liability           NaN         NaN         NaN            NaN
# 4           Property        Closed        Fire  2025-06-23     2025-06-30
# ..               ...           ...         ...         ...            ...
# 495        Collision           NaN         NaN         NaN            NaN
# 496         Property          Open   Liability  2025-06-02     2025-06-09
# 497        Liability           NaN         NaN         NaN            NaN
# 498        Collision        Closed       Theft  2025-12-07     2025-12-21
# 499         Property          Open        Fire  2025-02-25     2025-03-10
#
#     Distribution_Channel
# 0                 Online
# 1                 Direct
# 2                  Agent
# 3                  Agent
# 4                  Agent
# ..                   ...
# 495               Online
# 496               Direct
# 497                Agent
# 498                Agent
# 499               Direct
#
# [500 rows x 25 columns]>
# ['Policy_ID', 'Policy_Number', 'Customer_ID', 'State', 'Region', 'Product', 'Line_of_Business', 'Agent', 'Underwriter', 'Policy_Status', 'Risk_Level', 'Effective_Date', 'Expiration_Date', 'Written_Premium', 'Earned_Premium', 'Claim_Count', 'Claim_Amount', 'Paid_Claim_Amount', 'Outstanding_Reserve', 'Coverage_Type', 'Claim_Status', 'Claim_Type', 'Loss_Date', 'Reported_Date', 'Distribution_Channel']
# Policy_ID                 0
# Policy_Number             0
# Customer_ID               0
# State                     0
# Region                    0
# Product                   0
# Line_of_Business          0
# Agent                     0
# Underwriter               0
# Policy_Status             0
# Risk_Level                0
# Effective_Date            0
# Expiration_Date           0
# Written_Premium           0
# Earned_Premium            0
# Claim_Count               0
# Claim_Amount              0
# Paid_Claim_Amount         0
# Outstanding_Reserve       0
# Coverage_Type             0
# Claim_Status            314
# Claim_Type              314
# Loss_Date               314
# Reported_Date           314
# Distribution_Channel      0
# dtype: int64
# Claim_Count
# 0    314
# Name: count, dtype: int64

# %%
df['Claim_Status'] = df['Claim_Status'].fillna('No Claim')
df['Claim_Type'] = df['Claim_Type'].fillna('No Claim')

# %%
print(df['Claim_Status'].value_counts())
# Out:
# Claim_Status
# No Claim    314
# Closed      123
# Open         44
# Reopened     19
# Name: count, dtype: int64

# %%
df['Effective_Date'] = pd.to_datetime(df['Effective_Date'])
df['Expiration_Date'] = pd.to_datetime(df['Expiration_Date'])
df['Loss_Date'] = pd.to_datetime(df['Loss_Date'])
df['Reported_Date'] = pd.to_datetime(df['Reported_Date'])

# %%
bad_dates = df[df['Loss_Date'] < df['Effective_Date']]
print(f"Number of claims with Loss_Date before Effective_Date: {len(bad_dates)}")
# Out:
# Number of claims with Loss_Date before Effective_Date: 0

# %%
df = pd.read_csv('data/raw_claims.csv')
df['Claim_Status'] = df['Claim_Status'].fillna('No Claim')
df['Claim_Type'] = df['Claim_Type'].fillna('No Claim')

# %%
df['Effective_Date'] = pd.to_datetime(df['Effective_Date'])
df['Expiration_Date'] = pd.to_datetime(df['Expiration_Date'])
df['Loss_Date'] = pd.to_datetime(df['Loss_Date'])
df['Reported_Date'] = pd.to_datetime(df['Reported_Date'])

# %%
bad_dates = df[df['Loss_Date'] < df['Effective_Date']]
print(f"Number of claims with Loss_Date before Effective_Date: {len(bad_dates)}")
# Out:
# Number of claims with Loss_Date before Effective_Date: 0

# %%
df = pd.read_csv('data/raw_claims.csv')
df['Claim_Status'] = df['Claim_Status'].fillna('No Claim')
df['Claim_Type'] = df['Claim_Type'].fillna('No Claim')
df['Effective_Date'] = pd.to_datetime(df['Effective_Date'])
df['Expiration_Date'] = pd.to_datetime(df['Expiration_Date'])
df['Loss_Date'] = pd.to_datetime(df['Loss_Date'])
df['Reported_Date'] = pd.to_datetime(df['Reported_Date'])
bad_dates = df[df['Loss_Date'] < df['Effective_Date']]
print(f"Number of claims with Loss_Date before Effective_Date: {len(bad_dates)}")
# Out:
# Number of claims with Loss_Date before Effective_Date: 0

# %%
duplicate_count = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %%
df['Loss_Ratio'] = df['Claim_Amount']/df['Earned_Premium']
loss_ratio_by_product = df.groupby('Product') .agg(
    Total_Claims=('Claim_Amount', 'sum'),
    Total_Premium=('Earned_Premium','sum')
)
loss_ratio_by_product['Loss_Ratio']=loss_Ratio_by_product['Total_Claims']/loss_ratio_by_product['Total_Premium']
print(loss_ratio_by_product)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 6
#       2 loss_ratio_by_product = df.groupby('Product') .agg(
#       3     Total_Claims=('Claim_Amount', 'sum'),
#       4     Total_Premium=('Earned_Premium','sum')
#       5 )
# ----> 6 loss_ratio_by_product['Loss_Ratio']=loss_Ratio_by_product['Total_Claims']/loss_ratio_by_product['Total_Premium']
#       7 print(loss_ratio_by_product)
#
# NameError: name 'loss_Ratio_by_product' is not defined

# %%
df['Loss_Ratio'] = df['Claim_Amount']/df['Earned_Premium']
loss_ratio_by_product = df.groupby('Product') .agg(
    Total_Claims=('Claim_Amount', 'sum'),
    Total_Premium=('Earned_Premium','sum')
)
loss_ratio_by_product['Loss_Ratio']=loss_Ratio_by_product['Total_Claims']/loss_ratio_by_product['Total_Premium']
print(loss_ratio_by_product)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 6
#       2 loss_ratio_by_product = df.groupby('Product') .agg(
#       3     Total_Claims=('Claim_Amount', 'sum'),
#       4     Total_Premium=('Earned_Premium','sum')
#       5 )
# ----> 6 loss_ratio_by_product['Loss_Ratio']=loss_Ratio_by_product['Total_Claims']/loss_ratio_by_product['Total_Premium']
#       7 print(loss_ratio_by_product)
#
# NameError: name 'loss_Ratio_by_product' is not defined

# %%
df['Loss_Ratio'] = df['Claim_Amount']/df['Earned_Premium']
loss_ratio_by_product = df.groupby('Product') .agg(
    Total_Claims=('Claim_Amount', 'sum'),
    Total_Premium=('Earned_Premium','sum')
)
loss_ratio_by_product['Loss_Ratio']=loss_ratio_by_product['Total_Claims']/loss_ratio_by_product['Total_Premium']
print(loss_ratio_by_product)
# Out:
#                      Total_Claims  Total_Premium  Loss_Ratio
# Product
# Auto                    825969.31      204343.40    4.042065
# Commercial Auto         356708.95      398181.14    0.895846
# Commercial Property     109600.28      365862.02    0.299567
# Home                    498420.44      168433.94    2.959145

# %%
 loss_ratio_by_region = df.groupby('Region') .agg(
    Total_Claims=('Claim_Amount', 'sum'),
    Total_Premium=('Earned_Premium','sum')
)
loss_ratio_by_region['Loss_Ratio']=loss_ratio_by_region['Total_Claims']/loss_ratio_by_region['Total_Premium']
print(loss_ratio_by_region)
# Out:
#   Cell In[24], line 1
#     loss_ratio_by_region = df.groupby('Region') .agg(
#     ^
# IndentationError: unexpected indent

# %%
loss_ratio_by_region = df.groupby('Region') .agg(
    Total_Claims=('Claim_Amount', 'sum'),
    Total_Premium=('Earned_Premium','sum')
)
loss_ratio_by_region['Loss_Ratio']=loss_ratio_by_region['Total_Claims']/loss_ratio_by_region['Total_Premium']
print(loss_ratio_by_region)
# Out:
#            Total_Claims  Total_Premium  Loss_Ratio
# Region
# Midwest       283182.80      158964.72    1.781419
# Northeast     464956.79      405186.74    1.147512
# South         855440.97      447860.49    1.910061
# West          187118.42      124808.55    1.499244

# %%
loss_ratio_by_product_region = df.groupby('Product','Region') .agg(
    Total_Claims=('Claim_Amount', 'sum'),
    Total_Premium=('Earned_Premium','sum')
)
loss_ratio_by_product_region['Loss_Ratio']=loss_ratio_by_product_region['Total_Claims']/loss_ratio_by_product_region['Total_Premium']
print(loss_ratio_by_product_region)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 loss_ratio_by_product_region = df.groupby('Product','Region') .agg(
#       2     Total_Claims=('Claim_Amount', 'sum'),
#       3     Total_Premium=('Earned_Premium','sum')
#       4 )
#
# File ~/pnc-insurance-project/venv/lib/python3.13/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~/pnc-insurance-project/venv/lib/python3.13/site-packages/pandas/core/frame.py:10835, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10831
#   10832         if level is None and by is None:
#   10833             raise TypeError("You have to supply one of 'by' and 'level'")
#   10834
# > 10835         return DataFrameGroupBy(
#   10836             obj=self,
#   10837             keys=by,
#   10838             level=level,
#
# File ~/pnc-insurance-project/venv/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File ~/pnc-insurance-project/venv/lib/python3.13/site-packages/pandas/core/groupby/grouper.py:789, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     787 if isinstance(level, str):
#     788     if obj.index.name != level:
# --> 789         raise ValueError(f"level name {level} is not the name of the index")
#     790 elif level > 0 or level < -1:
#     791     raise ValueError("level > 0 or level < -1 only valid with MultiIndex")
#
# ValueError: level name Region is not the name of the index

# %%
loss_ratio_by_product_region = df.groupby(['Product','Region']) .agg(
    Total_Claims=('Claim_Amount', 'sum'),
    Total_Premium=('Earned_Premium','sum')
)
loss_ratio_by_product_region['Loss_Ratio']=loss_ratio_by_product_region['Total_Claims']/loss_ratio_by_product_region['Total_Premium']
print(loss_ratio_by_product_region)
# Out:
#                                Total_Claims  Total_Premium  Loss_Ratio
# Product             Region
# Auto                Midwest       135341.49       29660.85    4.562967
#                     Northeast     174691.91       60008.13    2.911137
#                     South         416713.98      101929.23    4.088268
#                     West           99221.93       12745.19    7.785049
# Commercial Auto     Midwest        44969.54       48220.60    0.932579
#                     Northeast      93804.85      150431.67    0.623571
#                     South         164878.09      160804.87    1.025330
#                     West           53056.47       38724.00    1.370119
# Commercial Property Midwest        45271.82       67902.16    0.666721
#                     Northeast      31397.30      128209.58    0.244890
#                     South          20580.95      109788.20    0.187460
#                     West           12350.21       59962.08    0.205967
# Home                Midwest        57599.95       13181.11    4.369886
#                     Northeast     165062.73       66537.36    2.480753
#                     South         253267.95       75338.19    3.361747
#                     West           22489.81       13377.28    1.681195
