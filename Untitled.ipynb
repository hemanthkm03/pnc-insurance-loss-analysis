# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///pnc_insurance.db')
df.to_sql('claims', engine, if_exists='replace', index=False)
print("Data loaded into SQLite database")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 from sqlalchemy import create_engine
#       2 engine = create_engine('sqlite:///pnc_insurance.db')
# ----> 3 df.to_sql('claims', engine, if_exists='replace', index=False)
#       4 print("Data loaded into SQLite database")
#
# NameError: name 'df' is not defined

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///pnc_insurance.db')
df.to_sql('claims', engine, if_exists='replace', index=False)
print("Data loaded into SQLite database")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 engine = create_engine('sqlite:///pnc_insurance.db')
# ----> 2 df.to_sql('claims', engine, if_exists='replace', index=False)
#       3 print("Data loaded into SQLite database")
#
# NameError: name 'df' is not defined

# %%
engine = create_engine('sqlite:///pnc_insurance.db')
df.to_sql('claims', engine, if_exists='replace', index=False)
print("Data loaded into SQLite database")
